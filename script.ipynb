# %%
# !which python
# Out:
# /opt/anaconda3/bin/python

# %%
pip show langchain | grep Location
# Out:
# Location: /opt/anaconda3/lib/python3.11/site-packages
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_google_genai import GoogleGenerativeAI

api_key = os.getenv('GOOGLE_API_KEY')
print(api_key)

#llm = GoogleGenerativeAI(model="gemini-pro", google_api_key=api_key)

#response = llm.predict("what are 3 car companies")

#print(response)
# Out:
# None

# %%
from langchain.utilities import SQLDatabase

db_user = "root"
db_pass = "root"
db_host = "localhost"
db_name = "atliq_shirts"

db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_pass}@{db_host}/{db_name}",sample_rows_in_table_info=3)

print(db.table_info)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
